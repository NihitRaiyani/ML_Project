# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card = pd.read_csv('creditcard.csv')

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5969  6634 -1.611463  0.190648  0.901715  1.531254 -1.535865  0.799245
# 5970  6635 -1.420272  1.449354  1.320110 -1.894320  0.913695  0.454601
# 5971  6637 -1.206696  0.284728  2.152053 -2.850437 -0.437285 -0.238376
# 5972  6644  1.067611  0.091006 -0.153917  0.704233  0.113894 -0.826866
# 5973  6645 -0.535272 -0.132299  2.180041  1.018303 -1.498819  0.529570
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5969  1.513786  0.495829  0.200390  ...  0.211223  0.007477  1.026272
# 5970  0.894179 -0.385450  2.433841  ... -0.529027 -0.368394 -0.247773
# 5971 -0.333341  0.334679  2.870542  ...  0.039460  0.464476 -0.457193
# 5972  0.567690 -0.464181  0.957295  ... -0.476723 -1.410090 -0.037550
# 5973  0.420147  0.045445  1.543919  ... -0.043098 -0.161548 -0.036483
#
#            V24       V25       V26       V27       V28      Amount     Class
# ...

# %%
credit_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5974 non-null   int64
#  1   V1      5974 non-null   float64
#  2   V2      5974 non-null   float64
#  3   V3      5974 non-null   float64
#  4   V4      5974 non-null   float64
#  5   V5      5974 non-null   float64
#  6   V6      5974 non-null   float64
#  7   V7      5974 non-null   float64
#  8   V8      5974 non-null   float64
#  9   V9      5974 non-null   float64
#  10  V10     5974 non-null   float64
#  11  V11     5974 non-null   float64
#  12  V12     5974 non-null   float64
#  13  V13     5974 non-null   float64
#  14  V14     5974 non-null   float64
#  15  V15     5974 non-null   float64
#  16  V16     5974 non-null   float64
#  17  V17     5974 non-null   float64
#  18  V18     5973 non-null   float64
#  19  V19     5973 non-null   float64
# ...

# %%
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card.fillna(credit_card.mean(), inplace=True)

# %%
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card['Class'].value_counts()
# Out:
# Class
# 0.000000    5970
# 1.000000       3
# 0.000502       1
# Name: count, dtype: int64

# %%
legit = credit_card[credit_card.Class == 0]
fraud = credit_card[credit_card.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (5970, 31)
# (3, 31)

# %%
legit.Amount.describe()
# Out:
# count    5970.000000
# mean       64.965707
# std       192.429839
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.485000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
credit_card.groupby('Class').mean()
# Out:
#                 Time        V1        V2        V3        V4        V5  \
# Class
# 0.000000  2677.40201 -0.264965  0.285625  0.844580  0.102656  0.000958
# 0.000502  6645.00000 -0.535272 -0.132299  2.180041  1.018303 -1.498819
# 1.000000  1780.00000 -2.553039  0.184644 -0.293711  2.872264  0.005330
#
#                 V6        V7        V8        V9  ...       V20       V21  \
# Class                                             ...
# 0.000000  0.195420  0.018542 -0.039195  0.397472  ...  0.055426 -0.043268
# 0.000502  0.529570  0.420147  0.045445  1.543919  ...  0.055700 -0.043098
# 1.000000 -0.855718 -0.549831  0.308239 -1.093098  ...  0.599742  0.294921
#
#                V22       V23       V24       V25       V26       V27  \
# Class
# 0.000000 -0.161540 -0.036683  0.028985  0.089890 -0.040132  0.025238
# 0.000502 -0.161548 -0.036483  0.028960  0.089873 -0.040197  0.025234
# 1.000000 -0.177321  0.361160 -0.020311  0.056068 -0.170050  0.015979
#
#                V28      Amount
# ...

# %%
legit_sample = legit.sample(n=500)

# %%
new_dataset = pd.concat([legit_sample, legit], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5498  5542 -0.786343  0.844867  2.080840  1.221750 -0.948287 -0.492227
# 4149  3747  1.451795 -0.600479 -0.885821 -1.637545  1.484024  3.265350
# 42      33 -0.607877  1.031345  1.740450  1.232106  0.418592  0.119168
# 5395  5349  1.168454 -0.376928  1.202268 -0.681310 -1.145168 -0.312766
# 3066  2625  1.345717 -1.328331  0.624539 -1.371451 -1.671559 -0.455365
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5498 -0.302298  0.339566  1.053002  ...  0.139753  0.711669 -0.035988
# 4149 -1.205030  0.717133  0.363184  ... -0.293932 -0.884477  0.104260
# 42    0.850893 -0.176267 -0.243501  ... -0.087329  0.258315 -0.264775
# 5395 -0.931386  0.048634  3.069130  ...  0.153397  0.856484 -0.086759
# 3066 -1.114487 -0.149910 -1.668635  ... -0.203554 -0.383325 -0.027135
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3453  2940 -0.658299  0.641664  2.027823 -0.224098  0.098350  0.822344
# 1336  1045 -1.119842 -0.321771  1.051559 -0.619304  0.719417 -0.528290
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3453  0.003463  0.384775  0.070106  ... -0.069986  0.055740 -0.317841
# 1336  1.079071 -0.398037  0.194018  ... -0.214617 -0.449084 -0.027874
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    500
# 1.0      3
# Name: count, dtype: int64

# %% [markdown]
# ## cant complete this due to very unbalanced datset
